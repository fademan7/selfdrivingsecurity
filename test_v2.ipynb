# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# # 당뇨병을 진단해봅시다.
#
# 0:-100 첫줄부터 아래에서 100번째까지
# 0:-1 왼쪽에서 오른쪽끝에서 2번째까지
# [-1] 오른쪽 마지막만
# -100: 아래에서 100번째부터 마지막까지

# %%
xy = np.loadtxt('./dataset_392.csv', delimiter=',', dtype=np.float32)
x_train = xy[0:500, 0:3]
y_train = xy[0:500, [3]]

x_test = xy[500:506, 0:3]
y_test = xy[500:506, [3]]

print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (500, 3) (500, 1)
# (6, 3) (6, 1)

# %%
print(x_test)
print(y_test)
# Out:
# [[1.5864828e-01 8.1448275e-01 1.7477594e-01]
#  [0.0000000e+00 1.0000000e+00 2.9899999e-23]
#  [0.0000000e+00 1.0000000e+00 1.1500000e-37]
#  [0.0000000e+00 1.0000000e+00 1.1500000e-37]
#  [0.0000000e+00 1.0000000e+00 1.1500000e-37]
#  [0.0000000e+00 1.0000000e+00 1.1500000e-37]]
# [[-1.0388241e+01]
#  [-1.4974511e+00]
#  [-1.5226110e-02]
#  [ 4.9998090e-03]
#  [ 4.0219938e-03]
#  [-3.6868080e-03]]

# %%
dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(len(x_train))

# %%
W = tf.Variable(tf.random.normal([3, 1]), name='weight')
b = tf.Variable(tf.random.normal([1]), name='bias')

# %% [markdown]
# ## 가설 설정
# * 병이 있다 / 없다로 분류
# * softmax classification으로 진행
#
# ## $$ y_k = \frac{exp(x_k)}{\sum_{i=1}^{n}exp(x_i)}  $$

# %%
def logistic_regression(features):
    hypothesis  = tf.divide(1., 1. + tf.exp(-(tf.matmul(features, W) + b)))
    return hypothesis
  
print(logistic_regression(x_train))
# Out:
# tf.Tensor(
# [[0.29177463]
#  [0.29183984]
#  [0.29019257]
#  [0.29149744]
#  [0.29603162]
#  [0.30273467]
#  [0.30595443]
#  [0.310732  ]
#  [0.30287227]
#  [0.3006418 ]
#  [0.30204904]
#  [0.29943538]
#  [0.2999595 ]
#  [0.29940778]
#  [0.31018123]
#  [0.2928293 ]
#  [0.302822  ]
#  [0.29923177]
#  [0.28793   ]
#  [0.28082028]
#  [0.3057923 ]
#  [0.28628013]
#  [0.27944738]
#  [0.30283627]
#  [0.30346242]
#  [0.29888678]
#  [0.3012154 ]
#  [0.3105539 ]
#  [0.3143606 ]
#  [0.3045667 ]
#  [0.30100214]
#  [0.30036896]
#  [0.30293128]
#  [0.30781534]
#  [0.30634508]
#  [0.30815762]
#  [0.3078053 ]
#  [0.30418918]
#  [0.30566925]
#  [0.3021837 ]
#  [0.299178  ]
#  [0.28541666]
#  [0.293687  ]
#  [0.29345113]
#  [0.3050837 ]
#  [0.3007962 ]
#  [0.30559945]
#  [0.30139485]
#  [0.30277622]
#  [0.3071143 ]
#  [0.30792102]
#  [0.3020735 ]
#  [0.31094402]
#  [0.30437216]
#  [0.2926201 ]
#  [0.30533257]
#  [0.30534083]
#  [0.3082116 ]
#  [0.30299014]
#  [0.28505093]
#  [0.30394706]
#  [0.30764106]
#  [0.3063591 ]
#  [0.31272137]
#  [0.30825227]
#  [0.30853003]
#  [0.3051138 ]
#  [0.30522972]
#  [0.30658162]
#  [0.2892731 ]
#  [0.29350007]
#  [0.3075336 ]
#  [0.29651967]
#  [0.29558086]
#  [0.2952571 ]
#  [0.29963404]
#  [0.30508068]
#  [0.3006259 ]
#  [0.3080755 ]
#  [0.30335382]
#  [0.30715013]
#  [0.3006708 ]
#  [0.30484053]
#  [0.31384027]
#  [0.30746603]
#  [0.30169284]
#  [0.29579154]
#  [0.29874647]
#  [0.29662085]
#  [0.29616314]
#  [0.30358344]
#  [0.3103657 ]
#  [0.3076567 ]
#  [0.30943966]
#  [0.3089164 ]
#  [0.30884048]
#  [0.30447263]
#  [0.3038758 ]
#  [0.30041045]
#  [0.2999668 ]
#  [0.31336913]
#  [0.31487167]
#  [0.30413654]
#  [0.31100518]
#  [0.30533832]
#  [0.29158378]
#  [0.303984  ]
#  [0.31187627]
#  [0.30535027]
#  [0.30024368]
#  [0.30853945]
#  [0.30294913]
#  [0.30485153]
#  [0.29379874]
#  [0.30625638]
#  [0.30760702]
#  [0.30059415]
#  [0.30629358]
#  [0.30363095]
#  [0.29965785]
#  [0.30700243]
#  [0.30293995]
#  [0.3038095 ]
#  [0.29997382]
#  [0.30385196]
#  [0.29887724]
#  [0.29207134]
#  [0.3065871 ]
#  [0.2998043 ]
#  [0.30772328]
#  [0.30918014]
#  [0.30686954]
#  [0.30679727]
#  [0.30218542]
#  [0.30075264]
#  [0.30051395]
#  [0.29867545]
#  [0.29937145]
#  [0.29940784]
#  [0.29944012]
#  [0.29943237]
#  [0.2993547 ]
#  [0.2898636 ]
#  [0.28911975]
#  [0.29020876]
#  [0.2882096 ]
#  [0.28803286]
#  [0.30768973]
#  [0.31028265]
#  [0.30847272]
#  [0.30938292]
#  [0.3074847 ]
#  [0.3077613 ]
#  [0.30630147]
#  [0.30585632]
#  [0.30607557]
#  [0.30592477]
#  [0.3121273 ]
#  [0.3096733 ]
#  [0.30799857]
#  [0.31442925]
#  [0.31173283]
#  [0.29581627]
#  [0.28470162]
#  [0.29375502]
#  [0.30282313]
#  [0.2918133 ]
#  [0.29275152]
#  [0.3022548 ]
#  [0.29686344]
#  [0.3034383 ]
#  [0.30980265]
#  [0.30125841]
#  [0.29969254]
#  [0.29849383]
#  [0.29711938]
#  [0.31123638]
#  [0.31241602]
#  [0.30919817]
#  [0.30983207]
#  [0.3103748 ]
#  [0.3112968 ]
#  [0.31331438]
#  [0.31231418]
#  [0.3118081 ]
#  [0.3114137 ]
#  [0.31112677]
#  [0.31214952]
#  [0.3138026 ]
#  [0.30794477]
#  [0.3129855 ]
#  [0.30575097]
#  [0.3046077 ]
#  [0.3061781 ]
#  [0.29476413]
#  [0.29831523]
#  [0.2996686 ]
#  [0.306171  ]
#  [0.29609525]
#  [0.29734695]
#  [0.29722115]
#  [0.2973559 ]
#  [0.31154335]
#  [0.30603662]
#  [0.3077917 ]
#  [0.31122938]
#  [0.311077  ]
#  [0.30912673]
#  [0.30995587]
#  [0.3117069 ]
#  [0.3130592 ]
#  [0.31262147]
#  [0.31208196]
#  [0.3138663 ]
#  [0.31273177]
#  [0.31162414]
#  [0.30806655]
#  [0.30601227]
#  [0.30235744]
#  [0.30842227]
#  [0.30621937]
#  [0.30780542]
#  [0.30644292]
#  [0.30647227]
#  [0.30116302]
#  [0.3059161 ]
#  [0.30685556]
#  [0.29706585]
#  [0.30013824]
#  [0.31141692]
#  [0.30586344]
#  [0.30773646]
#  [0.31152034]
#  [0.30924058]
#  [0.30938476]
#  [0.3116097 ]
#  [0.31291127]
#  [0.31239352]
#  [0.31033748]
#  [0.31097275]
#  [0.31005108]
#  [0.30971983]
#  [0.3094837 ]
#  [0.30935273]
#  [0.30910784]
#  [0.30821148]
#  [0.30823618]
#  [0.3084571 ]
#  [0.3121311 ]
#  [0.31546223]
#  [0.30950263]
#  [0.3124569 ]
#  [0.31234616]
#  [0.30397865]
#  [0.31058174]
#  [0.30869803]
#  [0.30993655]
#  [0.3093834 ]
#  [0.31372076]
#  [0.31402522]
#  [0.3125242 ]
#  [0.30980814]
#  [0.3105621 ]
#  [0.30718404]
#  [0.30789018]
#  [0.3089404 ]
#  [0.3093461 ]
#  [0.30889663]
#  [0.3090221 ]
#  [0.30731556]
#  [0.30709   ]
#  [0.29980838]
#  [0.2994316 ]
#  [0.29941714]
#  [0.2994593 ]
#  [0.29943544]
#  [0.29932934]
#  [0.29937875]
#  [0.29923448]
#  [0.2915824 ]
#  [0.2915824 ]
#  [0.2915824 ]
#  [0.2915824 ]
#  [0.2915824 ]
#  [0.2915824 ]
#  [0.29191166]
#  [0.29085937]
#  [0.29106683]
#  [0.29065463]
#  [0.29146653]
#  [0.3046514 ]
#  [0.30761808]
#  [0.31107146]
#  [0.30797043]
#  [0.3083256 ]
#  [0.30859643]
#  [0.30971423]
#  [0.31270686]
#  [0.31138462]
#  [0.30838716]
#  [0.30845723]
#  [0.30873558]
#  [0.31144983]
#  [0.31456324]
#  [0.311032  ]
#  [0.3100284 ]
#  [0.31384164]
#  [0.31395242]
#  [0.31462246]
#  [0.30478838]
#  [0.301594  ]
#  [0.29570886]
#  [0.2904663 ]
#  [0.30035397]
#  [0.3044204 ]
#  [0.30669177]
#  [0.30705798]
#  [0.3062926 ]
#  [0.3096214 ]
#  [0.30675763]
#  [0.30439404]
#  [0.30036926]
#  [0.3062021 ]
#  [0.31053227]
#  [0.3102757 ]
#  [0.30996364]
#  [0.31043327]
#  [0.31024277]
#  [0.30775416]
#  [0.30950478]
#  [0.31166136]
#  [0.31030667]
#  [0.3129481 ]
#  [0.30487087]
#  [0.2975331 ]
#  [0.2909067 ]
#  [0.28378832]
#  [0.28747708]
#  [0.28716144]
#  [0.29217198]
#  [0.30558732]
#  [0.29608548]
#  [0.29717037]
#  [0.29805124]
#  [0.2955757 ]
#  [0.29409447]
#  [0.29840115]
#  [0.3095687 ]
#  [0.31141385]
#  [0.30375093]
#  [0.30725637]
#  [0.3087338 ]
#  [0.30732226]
#  [0.30904132]
#  [0.31092775]
#  [0.31246185]
#  [0.31213   ]
#  [0.31214216]
#  [0.31516367]
#  [0.30979505]
#  [0.3075482 ]
#  [0.31051216]
#  [0.311802  ]
#  [0.31051484]
#  [0.3118302 ]
#  [0.30831116]
#  [0.30723926]
#  [0.30886874]
#  [0.30899432]
#  [0.30815998]
#  [0.3089155 ]
#  [0.30891714]
#  [0.30978417]
#  [0.31097257]
#  [0.31124055]
#  [0.30816284]
#  [0.30473468]
#  [0.30320033]
#  [0.30353686]
#  [0.3023605 ]
#  [0.3017688 ]
#  [0.31028488]
#  [0.30517474]
#  [0.30218038]
#  [0.3024424 ]
#  [0.30610347]
#  [0.30583584]
#  [0.30867317]
#  [0.3132387 ]
#  [0.31287214]
#  [0.31308305]
#  [0.3080132 ]
#  [0.30698508]
#  [0.30015728]
#  [0.30782625]
#  [0.31186384]
#  [0.3142628 ]
#  [0.31463122]
#  [0.31460366]
#  [0.31467685]
#  [0.31470105]
#  [0.29180515]
#  [0.29180515]
#  [0.29180515]
#  [0.29182413]
#  [0.29110903]
#  [0.2906171 ]
#  [0.2905952 ]
#  [0.29102072]
#  [0.2963242 ]
#  [0.30912188]
#  [0.30994037]
#  [0.30587196]
#  [0.30516762]
#  [0.3088008 ]
#  [0.30674964]
#  [0.30843008]
#  [0.30563506]
#  [0.31029493]
#  [0.31002215]
#  [0.30741146]
#  [0.31311384]
#  [0.31012163]
#  [0.31498203]
#  [0.31442484]
#  [0.3084867 ]
#  [0.280248  ]
#  [0.3021706 ]
#  [0.2973043 ]
#  [0.29305452]
#  [0.29249203]
#  [0.29800752]
#  [0.30460164]
#  [0.29980847]
#  [0.2963536 ]
#  [0.29189548]
#  [0.30417663]
#  [0.29000625]
#  [0.29639742]
#  [0.29499573]
#  [0.3070516 ]
#  [0.30383438]
#  [0.3013152 ]
#  [0.30886886]
#  [0.31548434]
#  [0.30641595]
#  [0.29672432]
#  [0.296038  ]
#  [0.30341762]
#  [0.29822263]
#  [0.2997082 ]
#  [0.2999675 ]
#  [0.30882952]
#  [0.29721406]
#  [0.29634854]
#  [0.31018466]
#  [0.3058099 ]
#  [0.3034905 ]
#  [0.3007798 ]
#  [0.29421347]
#  [0.2931536 ]
#  [0.2984454 ]
#  [0.29312977]
#  [0.29451153]
#  [0.30400693]
#  [0.30661517]
#  [0.30420402]
#  [0.30321547]
#  [0.30593994]
#  [0.30027682]
#  [0.2994073 ]
#  [0.30784172]
#  [0.29766837]
#  [0.2961808 ]
#  [0.29506493]
#  [0.2881733 ]
#  [0.29357797]
#  [0.29063824]
#  [0.28757766]
#  [0.28940052]
#  [0.28370178]
#  [0.28308567]
#  [0.28371283]
#  [0.28317156]
#  [0.28655314]
#  [0.2923111 ]
#  [0.30164775]
#  [0.28942302]
#  [0.29794663]
#  [0.28674003]
#  [0.30062827]
#  [0.30352107]
#  [0.29243785]
#  [0.2979834 ]
#  [0.30193102]
#  [0.29834777]
#  [0.29574692]
#  [0.28602585]
#  [0.28312397]
#  [0.28597212]], shape=(500, 1), dtype=float32)

# %% [markdown]
# ## Loss Function
#
# * 기존 MSE 대신 Cross Entropy 사용
#
# ## $$
# \begin{align}
# loss(h(x),y) & = −y log(h(x))−(1−y)log(1−h(x))
# \end{align}
# $$

# %%
def loss_fn(hypothesis, labels):
    loss = -tf.reduce_mean(labels * tf.math.log(hypothesis) + \
                           (1 - labels) * tf.math.log(1 - hypothesis))
    return loss

optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=0.001)

# %% [markdown]
# ## 학습

# %%
epochs = 5000

for step in range(epochs):
  for features, labels in dataset:
    with tf.GradientTape() as tape:
      loss_value = loss_fn(logistic_regression(features),labels)
      grads = tape.gradient(loss_value, [W,b])
      optimizer.apply_gradients(grads_and_vars=zip(grads,[W,b]))
      if step % 100 == 0:
            print("Iter: {}, Loss: {:.4f}".format(step, loss_fn(logistic_regression(features),labels)))
# Out:
# Iter: 0, Loss: -19.3960
# Iter: 100, Loss: -19.4926
# Iter: 200, Loss: -19.5892
# Iter: 300, Loss: -19.6858
# Iter: 400, Loss: -19.7824
# Iter: 500, Loss: -19.8790
# Iter: 600, Loss: -19.9756
# Iter: 700, Loss: -20.0722
# Iter: 800, Loss: -20.1688
# Iter: 900, Loss: -20.2654
# Iter: 1000, Loss: -20.3620
# Iter: 1100, Loss: -20.4586
# Iter: 1200, Loss: -20.5552
# Iter: 1300, Loss: -20.6518
# Iter: 1400, Loss: -20.7484
# Iter: 1500, Loss: -20.8449
# Iter: 1600, Loss: -20.9415
# Iter: 1700, Loss: -21.0381
# Iter: 1800, Loss: -21.1346
# Iter: 1900, Loss: -21.2311
# Iter: 2000, Loss: -21.3276
# Iter: 2100, Loss: -21.4241
# Iter: 2200, Loss: -21.5207
# Iter: 2300, Loss: -21.6172
# Iter: 2400, Loss: -21.7137
# Iter: 2500, Loss: -21.8102
# Iter: 2600, Loss: -21.9067
# Iter: 2700, Loss: -22.0032
# Iter: 2800, Loss: -22.0997
# Iter: 2900, Loss: -22.1962
# Iter: 3000, Loss: -22.2927
# Iter: 3100, Loss: -22.3891
# Iter: 3200, Loss: -22.4856
# Iter: 3300, Loss: -22.5821
# Iter: 3400, Loss: -22.6786
# Iter: 3500, Loss: -22.7750
# Iter: 3600, Loss: -22.8715
# Iter: 3700, Loss: -22.9679
# Iter: 3800, Loss: -23.0643
# Iter: 3900, Loss: -23.1608
# Iter: 4000, Loss: -23.2571
# Iter: 4100, Loss: -23.3535
# Iter: 4200, Loss: -23.4499
# Iter: 4300, Loss: -23.5463
# Iter: 4400, Loss: -23.6426
# Iter: 4500, Loss: -23.7390
# Iter: 4600, Loss: -23.8354
# Iter: 4700, Loss: -23.9317
# Iter: 4800, Loss: -24.0281
# Iter: 4900, Loss: -24.1245

# %% [markdown]
# ## 테스트

# %%
def accuracy_fn(hypothesis, labels):
    predicted = tf.cast(hypothesis > 0.5, dtype=tf.int32)
    accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, labels), dtype=tf.float32))
    return accuracy

# %%
test_acc = accuracy_fn(logistic_regression(x_test),y_test)
print("Testset Accuracy: {:.4f}".format(test_acc))
# Out:
# Testset Accuracy: 0.6667
